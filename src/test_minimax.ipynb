# %%
from board import Board
import gamemodes.wrapped_functions as funcs
from algorithms.minimax import minimax

import json

depth = 15
board_json = open("..\\resources\\tests\\minimax_test_5.json","r")
board_dict = json.loads(board_json.read())
board = Board(board_dict)

board.food = [{"x": 3, "y": 3}]

snake_id = board.get_self_id()
snake_2_id = "OTHER-SNAKE"
board.print_board()
# Out:
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ F O ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X

# %%
print("Self snake is top right, other snake bottom left")
print("Middle is hazard")
print(board.snakes[snake_id].get_body())
board.print_board()
# Out:
# Self snake is top right, other snake bottom left
# Middle is hazard
# [{'x': 3, 'y': 4}, {'x': 4, 'y': 4}, {'x': 4, 'y': 3}]
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ F O ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X

# %%
print("Base Board")
board.print_board()

mm = minimax(eval_function= funcs.wrapped_eval, gamemode= 'wrapped', debug_mode= False)
move_val = mm(board, depth= depth)

move = board.get_moves(board.snakes[snake_id].get_head())[move_val[0]]
print("CHOSEN MOVE:", move_val, move)
# Out:
# Base Board
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ F O ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# ___________________________________________________________________________
#
# MY_SNAKE up board
# Food eaten: 0
# X X X O X X
# X ◦ ◦ O O X
# X ◦ ◦ F ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# ______________________________________________________________________
#
# OTHER_SNAKE up board
# X X X O X X
# X ◦ ◦ O O X
# X ◦ ◦ F ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _________________________________________________________________
#
# MY_SNAKE up board
# Food eaten: 0
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ F ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# ____________________________________________________________
#
# OTHER_SNAKE up board
# X X X O X X
# X ◦ ◦ O ◦ X
# X O ◦ F ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _______________________________________________________
#
# MY_SNAKE up board
# Food eaten: 0
# X X X O X X
# X ◦ ◦ ◦ ◦ X
# X O ◦ F ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ O X X
#
# __________________________________________________
#
# OTHER_SNAKE up board
# X X X O X X
# X O ◦ ◦ ◦ X
# X ◦ ◦ F ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ O X X
#
# _____________________________________________
#
# MY_SNAKE up board
# Food eaten: 0
# X X X ◦ X X
# X O ◦ ◦ ◦ X
# X ◦ ◦ F ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ O X X
#
# ________________________________________
#
# OTHER_SNAKE up board
# X O X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ F ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ O X X
#
# ___________________________________
#
# MY_SNAKE up board
# Food eaten: 1
# X O X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ O X X
#
# ______________________________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X O ◦ O X X
#
# _________________________
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X O ◦ ◦ X X
#
# ____________________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X O ◦ O ◦ X
# X X ◦ ◦ X X
#
# _______________
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE down board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE left board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE right board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0.9, 'left': 0.9, 'right': 0.9}
#
# _______________
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X
# Self collision
#
# _______________
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ O O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X O O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': 0.8, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
#
# _______________
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ O X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O O ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O O
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
# 3 MY-SNAKE {'up': 1.0, 'down': -100, 'left': 0.1, 'right': 0.1}
#
# ____________________
#
# OTHER_SNAKE down board
# X O X ◦ X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ ◦ X X
#
# _______________
#
# MY_SNAKE up board
# Food eaten: 1
# X O X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE down board
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE left board
# O X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# O X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# O X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# O X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# O X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE right board
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X O O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -50, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0.9, 'left': 0.9, 'right': 0.9}
#
# _______________
#
# MY_SNAKE down board
# Food eaten: 1
# X O X ◦ X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# Self collision
#
# _______________
#
# MY_SNAKE left board
# Food eaten: 1
# X O X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X O O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': 0.8, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
#
# _______________
#
# MY_SNAKE right board
# Food eaten: 1
# X O X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ O X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O O
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
# 3 MY-SNAKE {'up': 1.0, 'down': -100, 'left': 0.1, 'right': 0.1}
#
# ____________________
#
# OTHER_SNAKE left board
# X X X ◦ X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# O X ◦ ◦ X X
#
# _______________
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# O X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE down board
# O X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# O X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# O X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# O X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# O X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE left board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X O
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X O
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X O
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X O
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X O
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE right board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0.9, 'left': 0.9, 'right': 0.9}
#
# _______________
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# O X ◦ ◦ X X
# Self collision
#
# _______________
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# O X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X O O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': 0.8, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
#
# _______________
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# O X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ O X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O O
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# O ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
# 3 MY-SNAKE {'up': 1.0, 'down': -100, 'left': 0.1, 'right': 0.1}
#
# ____________________
#
# OTHER_SNAKE right board
# X X X ◦ X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X O ◦ X X
#
# _______________
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X O ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE down board
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X O O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -50, 'right': -100}
#
# __________
#
# OTHER_SNAKE left board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE right board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
# 1 MY-SNAKE {'up': -50, 'down': -100, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0.9, 'left': 0.9, 'right': -49.9}
#
# _______________
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X O ◦ X X
# Self collision
#
# _______________
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X O ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X O O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': 0.8, 'right': -100}
#
# __________
#
# OTHER_SNAKE down board
# X X O ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X O ◦ X X
# X ◦ O O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O ◦ X X
# X O O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X O ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -50, 'down': 0.8, 'left': 0.8, 'right': -100}
#
# __________
#
# OTHER_SNAKE left board
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X O O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': 0.8, 'right': -100}
#
# __________
#
# OTHER_SNAKE right board
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X O O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': 0.8, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0.9, 'left': 0.9, 'right': 0.9}
#
# _______________
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X O ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ O X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O O
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
# 3 MY-SNAKE {'up': -49.8, 'down': -100, 'left': 1.0, 'right': 0.1}
# 4 OTHER-SNAKE {'up': 1.1, 'down': 1.1, 'left': 1.1, 'right': 1.1}
#
# _________________________
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X O ◦ ◦ X X
# Self collision
#
# _________________________
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X O ◦ ◦ X X
#
# ____________________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X O ◦ O ◦ X
# X X ◦ ◦ X X
#
# _______________
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ O ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ O ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O ◦ X X
# X ◦ O ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X O O ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ O O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': -100, 'left': 0.8, 'right': 0.8}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
#
# _______________
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ O O ◦ ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ O O O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ O O ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ O O ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ O O ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ O O O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': -50, 'right': 0.8}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
#
# _______________
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X O O O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X O O O ◦ ◦
# ◦ O ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ X X
# X O ◦ ◦ ◦ X
# X O O O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X O O O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# O O O O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X O O O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -50, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
#
# _______________
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X
# Self collision
# 3 MY-SNAKE {'up': 0.1, 'down': 0.1, 'left': 0.1, 'right': -100}
# 4 OTHER-SNAKE {'up': 0.2, 'down': 0, 'left': 0, 'right': 0}
#
# _________________________
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X O ◦ ◦ X X
#
# ____________________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ O ◦ ◦
# X O ◦ O ◦ X
# X X ◦ ◦ X X
#
# _______________
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ O X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ O ◦ ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ ◦ O X
# X ◦ ◦ O O ◦
# ◦ O ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ O X
# X ◦ ◦ ◦ O X
# X ◦ ◦ O O ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ O X
# X ◦ ◦ O O ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O O ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ O O
# X ◦ ◦ O O ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': -100, 'left': 0.8, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
#
# _______________
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ O O ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O O ◦
# ◦ O ◦ O O ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O O ◦
# ◦ O ◦ ◦ O ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O O ◦
# ◦ O ◦ ◦ O ◦
# X ◦ ◦ ◦ O X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O O ◦
# ◦ O ◦ O O ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O O ◦
# ◦ O ◦ ◦ O O
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': 0.8, 'right': 0.8}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
#
# _______________
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ O ◦ ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X
# Self collision
#
# _______________
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O O O
# ◦ ◦ ◦ O ◦ ◦
# X O ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O O O
# ◦ O ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ O
# X ◦ ◦ O O O
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O O O
# ◦ O ◦ ◦ ◦ O
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O O O
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# O ◦ ◦ O O O
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
# 3 MY-SNAKE {'up': 0.1, 'down': 0.1, 'left': -100, 'right': 0.1}
# 4 OTHER-SNAKE {'up': 0.2, 'down': 0, 'left': 0, 'right': 0}
# 5 MY-SNAKE {'up': 1.2000000000000002, 'down': -100, 'left': 0.1, 'right': 0.1}
#
# ______________________________
#
# OTHER_SNAKE down board
# X X X ◦ X X
# X O ◦ ◦ ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ O X X
#
# _________________________
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ ◦ X X
#
# ____________________
#
# OTHER_SNAKE up board
# X O X ◦ X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ ◦ X X
#
# _______________
#
# MY_SNAKE up board
# Food eaten: 1
# X O X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE down board
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE left board
# O X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# O X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# O X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# O X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# O X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE right board
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X O O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -50, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0.9, 'left': 0.9, 'right': 0.9}
#
# _______________
#
# MY_SNAKE down board
# Food eaten: 1
# X O X ◦ X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# Self collision
#
# _______________
#
# MY_SNAKE left board
# Food eaten: 1
# X O X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X O O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': 0.8, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
#
# _______________
#
# MY_SNAKE right board
# Food eaten: 1
# X O X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ O X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O O
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
# 3 MY-SNAKE {'up': 1.0, 'down': -100, 'left': 0.1, 'right': 0.1}
#
# ____________________
#
# OTHER_SNAKE down board
# X X X ◦ X X
# X ◦ ◦ O ◦ X
# X O ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ ◦ X X
#
# _______________
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X O ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE down board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE left board
# X X X O X X
# X ◦ ◦ O ◦ X
# O ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# O ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# O ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# O ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# O ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE right board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0.9, 'left': 0.9, 'right': 0.9}
#
# _______________
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O ◦ X
# X O ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# Self collision
#
# _______________
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X O ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X O O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O ◦ X X
# X O O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X O O O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X O O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X O O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': -50, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
#
# _______________
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X O ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X O ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ O X
# X O ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X O ◦ O O X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X O ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X O ◦ O O O
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
# 3 MY-SNAKE {'up': 1.0, 'down': -100, 'left': 0.1, 'right': 0.1}
#
# ____________________
#
# OTHER_SNAKE left board
# X X X ◦ X X
# O ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ ◦ X X
#
# _______________
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# O ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# O X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# O X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# O X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# O X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# O X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE down board
# X X X O X X
# X ◦ ◦ O ◦ X
# O ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# O ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# O ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# O ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# O ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE left board
# X X X O X X
# X ◦ ◦ O ◦ O
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ O
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ O
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ O
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ O
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE right board
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0.9, 'left': 0.9, 'right': 0.9}
#
# _______________
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# O ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# Self collision
#
# _______________
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# O ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# O X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# O X O ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# O X X ◦ X X
# X ◦ O O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# O X X ◦ X X
# X O O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# O X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': 0.8, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
#
# _______________
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# O ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# O X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# O X X ◦ O X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# O X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# O X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# O X X ◦ X X
# X ◦ ◦ O O O
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
# 3 MY-SNAKE {'up': 1.0, 'down': -100, 'left': 0.1, 'right': 0.1}
#
# ____________________
#
# OTHER_SNAKE right board
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ ◦ X X
#
# _______________
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X O O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -50, 'right': -100}
#
# __________
#
# OTHER_SNAKE down board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE left board
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE right board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -50, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0.9, 'left': 0.9, 'right': 0.9}
#
# _______________
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# Self collision
#
# _______________
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# Self collision
#
# _______________
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X O ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# ...
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -50, 'right': -100}
#
# __________
#
# OTHER_SNAKE down board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE left board
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X O ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -100, 'left': -100, 'right': -100}
#
# __________
#
# OTHER_SNAKE right board
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ O X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O O X X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X O O X
# X ◦ ◦ O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': -50, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0.9, 'left': 0.9, 'right': 0.9}
#
# _______________
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# Self collision
#
# _______________
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# Self collision
#
# _______________
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X O ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O ◦ O X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X O ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X O ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X O ◦ X X
# X ◦ ◦ O O O
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
# 3 MY-SNAKE {'up': 1.0, 'down': -100, 'left': -50, 'right': 0.1}
# 4 OTHER-SNAKE {'up': 1.1, 'down': 1.1, 'left': 1.1, 'right': 1.1}
#
# _________________________
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X O ◦ ◦ ◦ X
# X ◦ ◦ O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ ◦ X X
# Self collision
#
# _________________________
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X O ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ ◦ X X
#
# ____________________
#
# OTHER_SNAKE up board
# X O X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ ◦ X X
#
# _______________
#
# MY_SNAKE up board
# Food eaten: 1
# X O X ◦ X X
# X ◦ O ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ O ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X O ◦ X X
# X ◦ O ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X O O ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ O O ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': -100, 'left': 0.8, 'right': 0.8}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
#
# _______________
#
# MY_SNAKE down board
# Food eaten: 1
# X O X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ O O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ O O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ O ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ O ◦ ◦ ◦
# X ◦ O ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ O O ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ O O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': 0.8, 'left': 0.8, 'right': 0.8}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
#
# _______________
#
# MY_SNAKE left board
# Food eaten: 1
# X O X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X O O O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X O O O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ X X
# X O ◦ ◦ ◦ X
# X O O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X O O O ◦ ◦
# ◦ O ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# O O O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X O O O ◦ ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
# 1 MY-SNAKE {'up': 0.8, 'down': 0.8, 'left': -100, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
#
# _______________
#
# MY_SNAKE right board
# Food eaten: 1
# X O X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ O O ◦ ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
# Self collision
# 3 MY-SNAKE {'up': 0.1, 'down': 0.1, 'left': 0.1, 'right': -100}
# 4 OTHER-SNAKE {'up': 0.2, 'down': 0, 'left': 0, 'right': 0}
#
# _________________________
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X O ◦ ◦ ◦ X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ ◦ X X
#
# ____________________
#
# OTHER_SNAKE up board
# X O X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ O ◦ X
# X X ◦ ◦ X X
#
# _______________
#
# MY_SNAKE up board
# Food eaten: 1
# X O X ◦ X X
# X ◦ ◦ ◦ O X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# X X X ◦ X X
# X ◦ ◦ ◦ O X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ O ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE up board
# Food eaten: 1
# X X X ◦ O X
# X ◦ ◦ ◦ O X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE down board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ O X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE left board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ O O X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
#
# _____
#
# MY_SNAKE right board
# Food eaten: 1
# X X X ◦ X X
# X ◦ ◦ ◦ O O
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ ◦ ◦ ◦
# X ◦ ◦ ◦ ◦ X
# X O ◦ ◦ X X
# 1 MY-SNAKE {'up': -100, 'down': -100, 'left': 0.8, 'right': -100}
# 2 OTHER-SNAKE {'up': 0.9, 'down': 0, 'left': 0, 'right': 0}
#
# _______________
#
# MY_SNAKE down board
# Food eaten: 1
# X O X ◦ X X
# X ◦ ◦ ◦ ◦ X
# X ◦ ◦ O O ◦
# ◦ ◦ ◦ O O ◦
# X ◦ ◦ ◦ ◦ X
# X X ◦ ◦ X X
#
# __________
#
# OTHER_SNAKE up board
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\adamc\AppData\Local\Programs\Python\Python310\lib\copy.py:254, in _keep_alive(x, memo)
#     253 try:
# --> 254     memo[id(memo)].append(x)
#     255 except KeyError:
#     256     # aha, this is the first one :-)
#
# KeyError: 2385333772480
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\adamc\OneDrive\Documents\GitHub\BattleSnake\src\test_minimax.ipynb Cell 3 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/adamc/OneDrive/Documents/GitHub/BattleSnake/src/test_minimax.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> board.print_board()
#       <a href='vscode-notebook-cell:/c%3A/Users/adamc/OneDrive/Documents/GitHub/BattleSnake/src/test_minimax.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> mm = minimax(eval_function= funcs.wrapped_eval, gamemode= 'wrapped', debug_mode= True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/adamc/OneDrive/Documents/GitHub/BattleSnake/src/test_minimax.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> move_val = mm(board, depth= depth)
#       <a href='vscode-notebook-cell:/c%3A/Users/adamc/OneDrive/Documents/GitHub/BattleSnake/src/test_minimax.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> move = board.get_moves(board.snakes[snake_id].get_head())[move_val[0]]
#       <a href='vscode-notebook-cell:/c%3A/Users/adamc/OneDrive/Documents/GitHub/BattleSnake/src/test_minimax.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> print("CHOSEN MOVE:", move_val, move)
#
# File c:\Users\adamc\OneDrive\Documents\GitHub\BattleSnake\src\algorithms\minimax.py:22, in minimax.__call__(self, board, depth, snake_id)
#      20     minimax_score = self._minimax(snake_id, board, depth)
#      21 else:
# ---> 22     minimax_score = self._minimax(board.get_self_id(), board, depth)
#      23 return minimax_score
#
# File c:\Users\adamc\OneDrive\Documents\GitHub\BattleSnake\src\algorithms\minimax.py:105, in minimax._minimax(self, snake_id, board, depth, alpha, beta, food_count)
#     102     print(f"Food eaten: {move_food + food_count}")
#     103     move_board.print_board()
# --> 105 move_scores[move] = self._minimax(next_snake_id, move_board, depth-1, alpha, beta, food_count+move_food)[1]
#     106 if self.alpha_beta:
#     107     if move_scores[move] >= beta:
#
# File c:\Users\adamc\OneDrive\Documents\GitHub\BattleSnake\src\algorithms\minimax.py:132, in minimax._minimax(self, snake_id, board, depth, alpha, beta, food_count)
#     129 if self.debug_mode:
#     130     move_board.print_board()
# --> 132 move_scores[move] = self._minimax(next_snake_id, move_board, depth-1, alpha, beta, food_count)[1]
#     133 if self.alpha_beta:
#     134     if move_scores[move] <= alpha:
#
# File c:\Users\adamc\OneDrive\Documents\GitHub\BattleSnake\src\algorithms\minimax.py:105, in minimax._minimax(self, snake_id, board, depth, alpha, beta, food_count)
#     102     print(f"Food eaten: {move_food + food_count}")
#     103     move_board.print_board()
# --> 105 move_scores[move] = self._minimax(next_snake_id, move_board, depth-1, alpha, beta, food_count+move_food)[1]
#     106 if self.alpha_beta:
#     107     if move_scores[move] >= beta:
#
# File c:\Users\adamc\OneDrive\Documents\GitHub\BattleSnake\src\algorithms\minimax.py:132, in minimax._minimax(self, snake_id, board, depth, alpha, beta, food_count)
#     129 if self.debug_mode:
#     130     move_board.print_board()
# --> 132 move_scores[move] = self._minimax(next_snake_id, move_board, depth-1, alpha, beta, food_count)[1]
#     133 if self.alpha_beta:
#     134     if move_scores[move] <= alpha:
#
#     [... skipping similar frames: minimax._minimax at line 105 (4 times), minimax._minimax at line 132 (3 times)]
#
# File c:\Users\adamc\OneDrive\Documents\GitHub\BattleSnake\src\algorithms\minimax.py:132, in minimax._minimax(self, snake_id, board, depth, alpha, beta, food_count)
#     129 if self.debug_mode:
#     130     move_board.print_board()
# --> 132 move_scores[move] = self._minimax(next_snake_id, move_board, depth-1, alpha, beta, food_count)[1]
#     133 if self.alpha_beta:
#     134     if move_scores[move] <= alpha:
#
# File c:\Users\adamc\OneDrive\Documents\GitHub\BattleSnake\src\algorithms\minimax.py:105, in minimax._minimax(self, snake_id, board, depth, alpha, beta, food_count)
#     102     print(f"Food eaten: {move_food + food_count}")
#     103     move_board.print_board()
# --> 105 move_scores[move] = self._minimax(next_snake_id, move_board, depth-1, alpha, beta, food_count+move_food)[1]
#     106 if self.alpha_beta:
#     107     if move_scores[move] >= beta:
#
# File c:\Users\adamc\OneDrive\Documents\GitHub\BattleSnake\src\algorithms\minimax.py:128, in minimax._minimax(self, snake_id, board, depth, alpha, beta, food_count)
#     126 move_board = copy.deepcopy(board)
#     127 move_board.move(snake_id, potential_moves[move])
# --> 128 move_board.update_board_after_move() # Make more efficient
#     129 if self.debug_mode:
#     130     move_board.print_board()
#
# File c:\Users\adamc\OneDrive\Documents\GitHub\BattleSnake\src\board.py:269, in Board.update_board_after_move(self)
#     264 def update_board_after_move(self):
#     265     # self.update_data()
#     266     # Lowers HP, remove dead snakes, remove food
#     268     self.snakes = {snake: self.snakes[snake].update(self) for snake in self.snakes}
# --> 269     new_snakes = deepcopy(self.snakes)
#     270     food_removed = 0
#     271     for snake_id in self.snakes:
#
# File c:\Users\adamc\AppData\Local\Programs\Python\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File c:\Users\adamc\AppData\Local\Programs\Python\Python310\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File c:\Users\adamc\AppData\Local\Programs\Python\Python310\lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File c:\Users\adamc\AppData\Local\Programs\Python\Python310\lib\copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File c:\Users\adamc\AppData\Local\Programs\Python\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File c:\Users\adamc\AppData\Local\Programs\Python\Python310\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File c:\Users\adamc\AppData\Local\Programs\Python\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File c:\Users\adamc\AppData\Local\Programs\Python\Python310\lib\copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# File c:\Users\adamc\AppData\Local\Programs\Python\Python310\lib\copy.py:177, in deepcopy(x, memo, _nil)
#     175 if y is not x:
#     176     memo[d] = y
# --> 177     _keep_alive(x, memo) # Make sure x lives at least as long as d
#     178 return y
#
# File c:\Users\adamc\AppData\Local\Programs\Python\Python310\lib\copy.py:257, in _keep_alive(x, memo)
#     254     memo[id(memo)].append(x)
#     255 except KeyError:
#     256     # aha, this is the first one :-)
# --> 257     memo[id(memo)]=[x]
#
# KeyboardInterrupt:

# %%
print("Move")
board.move(snake_id, move)
board.update_board_after_move()
print(board.snakes[snake_id].get_body())
board.print_board()

# %%
print("Enemy move")
board.move(snake_2_id, {"x": 1, "y": 3})
board.print_board()
